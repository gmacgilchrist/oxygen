# %%
import xarray as xr

# %%
rootdir = '/projects/SOCCOM/datasets/goship-easyocean'
local = 'gridded'
basin = 'atlantic'
section = 'A02'
filename = 'a02.nc'
path = '/'.join([rootdir,local,basin,section,filename])
print(path)
ds = xr.open_dataset(path)
# Out:
# /projects/SOCCOM/datasets/goship-easyocean/gridded/atlantic/A02/a02.nc

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                   (gridded_section: 3, longitude: 396, latitude: 1,
#                                pressure: 651)
# Coordinates:
#   * gridded_section           (gridded_section) float64 1.0 2.0 3.0
#   * longitude                 (longitude) float64 -50.1 -50.0 ... -10.7 -10.6
#   * latitude                  (latitude) float64 46.41
#   * pressure                  (pressure) float64 0.0 10.0 ... 6.49e+03 6.5e+03
# Data variables:
#     time                      (longitude, gridded_section) datetime64[ns] ...
#     temperature               (pressure, latitude, longitude, gridded_section) float64 ...
#     practical_salinity        (pressure, latitude, longitude, gridded_section) float64 ...
#     oxygen                    (pressure, latitude, longitude, gridded_section) float64 ...
#     conservative_temperature  (pressure, latitude, longitude, gridded_section) float64 ...
# ...

# %%
ds['oxygen'].isel(gridded_section=0,latitude=0).plot()
