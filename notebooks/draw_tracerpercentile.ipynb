# %% [markdown]
# ## Visualize evaluated tracer percentile

# %%
import xarray as xr
from static import *

# %%
tracername = 'o2'
dataset = 'esm4' # gobai, esm4, ...
ascending = False

# %%
ds_tp = xr.open_dataset(path_tp(tracername,dataset,ascending))

# %% [markdown]
# ### Continuous in time

# %%
(ds_tp['Tp']-ds_tp['Tp'].mean('time')).plot(y='percentile')

# %%
tracername = 'o2sat'
dataset = 'esm4' # gobai, esm4, ...
ascending = False

# %%
ds_tp = xr.open_dataset(path_tp(tracername,dataset,ascending))

# %% [markdown]
# ### Continuous in time

# %%
(ds_tp['Tp']-ds_tp['Tp'].mean('time')).plot(y='percentile')
